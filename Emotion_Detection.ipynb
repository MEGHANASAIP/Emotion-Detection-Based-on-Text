# %% [markdown]
# <a href="https://colab.research.google.com/github/MEGHANASAIP/Emotion-Detection-Based-on-Text/blob/main/Emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Emotion_classify_Data.csv')

# %%
df.head()
# Out:
#                                              Comment Emotion
# 0  i seriously hate one subject to death but now ...    fear
# 1                 im so full of life i feel appalled   anger
# 2  i sit here to write i start to dig out my feel...    fear
# 3  ive been really angry with r and i feel like a...     joy
# 4  i feel suspicious if there is no one outside l...    fear

# %%
df.Emotion.value_counts()
# Out:
# Emotion
# anger    2000
# joy      2000
# fear     1937
# Name: count, dtype: int64

# %%
di={'anger':0,
    'joy':1,
    'fear':2}

# %%
df['classifier']=df['Emotion'].map(di)

# %%
df.head()
# Out:
#                                              Comment Emotion  classifier
# 0  i seriously hate one subject to death but now ...    fear           2
# 1                 im so full of life i feel appalled   anger           0
# 2  i sit here to write i start to dig out my feel...    fear           2
# 3  ive been really angry with r and i feel like a...     joy           1
# 4  i feel suspicious if there is no one outside l...    fear           2

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df.Comment,df.classifier,test_size=0.2,stratify=df.classifier,random_state=2025)

# %%
X_train.shape
# Out:
# (4749,)

# %%
X_test.shape
# Out:
# (1188,)

# %%
Y_train.shape
# Out:
# (4749,)

# %%
Y_test.shape
# Out:
# (1188,)

# %%
Y_train.value_counts()
# Out:
# classifier
# 1    1600
# 0    1600
# 2    1549
# Name: count, dtype: int64

# %%
Y_test.value_counts()
# Out:
# classifier
# 1    400
# 0    400
# 2    388
# Name: count, dtype: int64

# %% [markdown]
# Attempt 1 :
#
# using the sklearn pipeline module create a classification pipeline to classify the data.
#
#
# Note:
#
# using CountVectorizer with only trigrams.
# use RandomForest as the classifier.
# print the classification report.

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
clf = Pipeline([
    ('v', CountVectorizer(ngram_range=(3, 3))), ('r', RandomForestClassifier())
])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('v', CountVectorizer(ngram_range=(3, 3))),
#                 ('r', RandomForestClassifier())])

# %%
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.36      0.43       400
#            1       0.54      0.23      0.32       400
#            2       0.39      0.76      0.52       388
#
#     accuracy                           0.45      1188
#    macro avg       0.49      0.45      0.42      1188
# weighted avg       0.49      0.45      0.42      1188

# %% [markdown]
# Attempt 2 :
#
# using the sklearn pipeline module create a classification pipeline to classify the data.
#
# Note:
#
# using CountVectorizer with both unigram and bigrams.
# use Multinomial Naive Bayes as the classifier.
# print the classification report.

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = Pipeline([
    ('v', CountVectorizer(ngram_range=(1, 2))), ('nb', MultinomialNB())
])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('v', CountVectorizer(ngram_range=(1, 2))),
#                 ('nb', MultinomialNB())])

# %%
Y_pred=clf.predict(X_test)

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.85       400
#            1       0.89      0.85      0.87       400
#            2       0.87      0.86      0.87       388
#
#     accuracy                           0.86      1188
#    macro avg       0.87      0.86      0.86      1188
# weighted avg       0.87      0.86      0.86      1188

# %% [markdown]
# Attempt 3 :
#
# using the sklearn pipeline module create a classification pipeline to classify the data.
#
# Note:
#
# using CountVectorizer with both unigram and bigrams.
# use RandomForest as the classifier.
# print the classification report.

# %%
clf = Pipeline([
    ('v', CountVectorizer(ngram_range=(1, 2))), ('r', RandomForestClassifier())
])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('v', CountVectorizer(ngram_range=(1, 2))),
#                 ('r', RandomForestClassifier())])

# %%
Y_pred=clf.predict(X_test)

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       400
#            1       0.86      0.94      0.90       400
#            2       0.94      0.88      0.91       388
#
#     accuracy                           0.90      1188
#    macro avg       0.91      0.90      0.91      1188
# weighted avg       0.91      0.90      0.91      1188

# %% [markdown]
# Attempt 4 :
#
# using the sklearn pipeline module create a classification pipeline to classify the Data.
#
# Note:
#
# using TF-IDF vectorizer for pre-processing the text.
# use RandomForest as the classifier.
# print the classification report.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
clf=Pipeline([
    ('tfidf',TfidfVectorizer()),
    ('r',RandomForestClassifier())
])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('r', RandomForestClassifier())])

# %%
Y_pred=clf.predict(X_test)

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       400
#            1       0.88      0.94      0.91       400
#            2       0.94      0.89      0.91       388
#
#     accuracy                           0.91      1188
#    macro avg       0.91      0.91      0.91      1188
# weighted avg       0.91      0.91      0.91      1188

# %% [markdown]
# Use text pre-processing to remove stop words, punctuations and apply lemmatization

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
def preprocess(text):
  doc=nlp(text)
  filtered_tokens=[]
  for token in doc:
    if token.is_stop or token.is_punct:
      continue
    filtered_tokens.append(token.lemma_)
  return " ".join(filtered_tokens)

# %%
df['preprocessed_comment']=df['Comment'].apply(preprocess)

# %%
df.head()
# Out:
#                                              Comment Emotion  classifier  \
# 0  i seriously hate one subject to death but now ...    fear           2
# 1                 im so full of life i feel appalled   anger           0
# 2  i sit here to write i start to dig out my feel...    fear           2
# 3  ive been really angry with r and i feel like a...     joy           1
# 4  i feel suspicious if there is no one outside l...    fear           2
#
#                                 preprocessed_comment
# 0   seriously hate subject death feel reluctant drop
# 1                               m life feel appalled
# 2  sit write start dig feeling think afraid accep...
# 3             ve angry r feel like idiot trust place
# 4        feel suspicious outside like rapture happen

# %%
df['Comment'][0]
# Out:
# 'i seriously hate one subject to death but now i feel reluctant to drop it'

# %%
df['preprocessed_comment'][0]
# Out:
# 'seriously hate subject death feel reluctant drop'

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df.preprocessed_comment,df.classifier,test_size=0.2,stratify=df.classifier,random_state=2025)

# %% [markdown]
# Let's check the scores with our best model till now
#
# Random Forest
#
# Attempt1 :
#
# using the sklearn pipeline module create a classification pipeline to classify the data.
#
# Note:
#
# using CountVectorizer with both unigrams and bigrams.
# use RandomForest as the classifier.
# print the classification report.

# %%
clf = Pipeline([
    ('v', CountVectorizer(ngram_range=(1, 2))), ('r', RandomForestClassifier())
])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('v', CountVectorizer(ngram_range=(1, 2))),
#                 ('r', RandomForestClassifier())])

# %%
Y_pred=clf.predict(X_test)

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       400
#            1       0.95      0.94      0.94       400
#            2       0.92      0.92      0.92       388
#
#     accuracy                           0.93      1188
#    macro avg       0.93      0.93      0.93      1188
# weighted avg       0.93      0.93      0.93      1188

# %% [markdown]
# Attempt 2 :
#
# using the sklearn pipeline module create a classification pipeline to classify the data.
#
# Note:
#
# using TF-IDF vectorizer for pre-processing the text.
# use RandomForest as the classifier.
# print the classification report.

# %%
clf=Pipeline([
    ('tfidf',TfidfVectorizer()),
    ('r',RandomForestClassifier())
])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('r', RandomForestClassifier())])

# %%
Y_pred=clf.predict(X_test)

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       400
#            1       0.94      0.94      0.94       400
#            2       0.93      0.93      0.93       388
#
#     accuracy                           0.93      1188
#    macro avg       0.93      0.93      0.93      1188
# weighted avg       0.93      0.93      0.93      1188
